# %% [markdown]
# # Code to Scrape the Team Schedules for 2013 - 2023

# %%
#import packages for scraping
import os
import pandas as pd
import time
from urllib.request import urlopen
from bs4 import BeautifulSoup

#save path for csv files
savepath_csv = '/Users/nya/NBA project/NBA Project/00/scraped datasets'

#seasons schedules to scrape
season_list = ['2013','2014','2015','2016','2017','2018','2019','2020','2021','2022','2023']

#NBA teams to scrape (this dictionary is valid (complete) for 2013-2023 seasons)
team_dict = {
    'ATL': 'Atlanta Hawks',
    'BOS': 'Boston Celtics',
    'BRK': 'Brooklyn Nets',
    'CHA': 'Charlotte Bobcats',
    'CHI': 'Chicago Bulls',
    'CHO': 'Charlotte Hornets',
    'CLE': 'Cleveland Cavaliers',
    'DAL': 'Dallas Mavericks',
    'DEN': 'Denver Nuggets',
    'DET': 'Detroit Pistons',
    'GSW': 'Golden State Warriors',
    'HOU': 'Houston Rockets',
    'IND': 'Indiana Pacers',
    'LAC': 'Los Angeles Clippers',
    'LAL': 'Los Angeles Lakers',
    'MEM': 'Memphis Grizzlies',
    'MIA': 'Miami Heat',
    'MIL': 'Milwaukee Bucks',
    'MIN': 'Minnesota Timberwolves',
    'NOH': 'New Orleans Hornets',
    'NOP': 'New Orleans Pelicans',
    'NYK': 'New York Knicks',
    'OKC': 'Oklahoma City Thunder',
    'ORL': 'Orlando Magic',
    'PHI': 'Philadelphia 76ers',
    'PHO': 'Phoenix Suns',
    'POR': 'Portland Trail Blazers',
    'SAC': 'Sacramento Kings',
    'SAS': 'San Antonio Spurs',
    'TOR': 'Toronto Raptors',
    'UTA': 'Utah Jazz',
    'WAS': 'Washington Wizards'   
}

#teams that moved or otherwise had a name change - need to handle these teams separately (this dictionary is valid for 2013-2023)
teams_relocate_rename_dict = {
    'CHA': ['2013','2014'],
    'CHO': ['2015', '2016', '2017', '2018', '2019','2020','2021','2022','2023'],
    'NOH': ['2013'],
    'NOP': ['2014', '2015', '2016', '2017', '2018', '2019','2020','2021','2022','2023'],}
#---------------------Define Functions-----------------------

def sched_scrape_clean_process(team_abrv,year,team_dict):
    
    """
    This function scrapes season schedules. It has three inputs: team_abrv (a string; i.e. 'POR'),a year (a string; i.e. '2017'),
    and a dictionary containing team names; Output is a dataframe with schedule information.
    """
    #website URL to scrape 
    url = "https://www.basketball-reference.com/teams/{}/{}_games.html". format(team_abrv,year)
    html = urlopen(url)
    
    soup = BeautifulSoup(html,features="lxml")

    # use findALL() to get the column headers
    soup.findAll('tr', limit=1)

    #find all rows in table
    rows = soup.findAll('tr')
    sched_data = [[td.getText() for td in rows[i].findAll('td')] for i in range(len(rows))]

    #create a panda frame 
    sched_df = pd.DataFrame(sched_data)

    #drop columns that aren't needed (keeping date, home/away, opponent, OT info)
    sched_df.drop(columns = [1,2,3,6,8,9,10,11,12,13], inplace = True)

    #add column headers
    sched_df.columns = ['Date','Away_flag','Opponent','OT_flag']

    #drop empty rows (empty rows exist due to table formatting, not missing data)
    sched_df.dropna(subset = ['Date'], inplace = True)

    #add a column indicating the game number for a given season
    sched_df.reset_index(inplace = True)
    sched_df['Game_num'] = sched_df.index + 1

    #add a column indicating the team
    sched_df['Team'] = team_dict[team_abrv]

    #add a column indicating the year in which the season begins
    sched_df['Year'] = str(int(year) - 1)
    
    #reorder columns
    sched_df = sched_df[['Team','Year', 'Game_num','Date','Away_flag','Opponent','OT_flag']]

    return sched_df

#------------------------Scrape Data--------------------------------------
#create an empty data frame to hold the schedules for all teams, all seasons 
all_teams_sched_df = pd.DataFrame()

"""
The loop below scrapes schedule data. 
- Loops over team and loops over year. 
"""
for team in team_dict:
    team_sched_df = pd.DataFrame(columns=['Team', 'Year', 'Game_num', 'Date', 'Away_flag', 'Opponent', 'OT_flag'])  # create empty dataframe with column headers
    if team not in teams_relocate_rename_dict:  # for those teams that didn't (a) change cities, or (b) otherwise have a name change
        for year in season_list:
            single_season_df = sched_scrape_clean_process(team, year, team_dict)
            team_sched_df = pd.concat([team_sched_df, single_season_df], ignore_index=True)
            print('Scraped {} {} game schedule'.format(team, year))
            # Add a pause to keep web server happy
            time.sleep(15)
        print('Scraped multi-season schedule - {} game schedule {} - {}'.format(team, season_list[0], season_list[-1]))
    else:
        for year in teams_relocate_rename_dict[team]:  # for those team that either moved or otherwise had a name change
            single_season_df = sched_scrape_clean_process(team, year, team_dict)
            team_sched_df = pd.concat([team_sched_df, single_season_df], ignore_index=True)
            print('Scraped {} {} game schedule'.format(team, year))
            # Add a pause to keep web server happy
            time.sleep(15)
        print('Scraped multi-season schedule - {} game schedule {} - {}'.format(team, season_list[0], season_list[-1]))

    # append 'master schedule' data frame with team's schedule
    all_teams_sched_df = pd.concat([all_teams_sched_df, team_sched_df], ignore_index=True)

    print("Finished scraping for team:", team)  # Print after scraping each team's data

    #append 'master schedule' data frame with team's schedule
    all_teams_sched_df = pd.concat([all_teams_sched_df, team_sched_df], ignore_index=True)   

#-------------------------Save Data-----------------------------
print('Saving master file')

#save 'master schedule' file as csv
filename = 'all_teams_schedule_{}_{}.csv'.format(season_list[0], season_list[-1])
filename= os.path.join(savepath_csv,filename)
all_teams_sched_df.to_csv(filename)

print('Finished')
# Out:
# Scraped ATL 2013 game schedule
# Scraped ATL 2014 game schedule
# Scraped ATL 2015 game schedule
# Scraped ATL 2016 game schedule
# Scraped ATL 2017 game schedule
# Scraped ATL 2018 game schedule
# Scraped ATL 2019 game schedule
# Scraped ATL 2020 game schedule
# Scraped ATL 2021 game schedule
# Scraped ATL 2022 game schedule
# Scraped ATL 2023 game schedule
# Scraped multi-season schedule - ATL game schedule 2013 - 2023
# Finished scraping for team: ATL
# Scraped BOS 2013 game schedule
# Scraped BOS 2014 game schedule
# Scraped BOS 2015 game schedule
# Scraped BOS 2016 game schedule
# Scraped BOS 2017 game schedule
# Scraped BOS 2018 game schedule
# Scraped BOS 2019 game schedule
# Scraped BOS 2020 game schedule
# Scraped BOS 2021 game schedule
# Scraped BOS 2022 game schedule
# Scraped BOS 2023 game schedule
# Scraped multi-season schedule - BOS game schedule 2013 - 2023
# Finished scraping for team: BOS
# Scraped BRK 2013 game schedule
# Scraped BRK 2014 game schedule
# Scraped BRK 2015 game schedule
# Scraped BRK 2016 game schedule
# Scraped BRK 2017 game schedule
# Scraped BRK 2018 game schedule
# Scraped BRK 2019 game schedule
# Scraped BRK 2020 game schedule
# Scraped BRK 2021 game schedule
# Scraped BRK 2022 game schedule
# Scraped BRK 2023 game schedule
# Scraped multi-season schedule - BRK game schedule 2013 - 2023
# Finished scraping for team: BRK
# Scraped CHA 2013 game schedule
# Scraped CHA 2014 game schedule
# Scraped multi-season schedule - CHA game schedule 2013 - 2023
# Finished scraping for team: CHA
# Scraped CHI 2013 game schedule
# Scraped CHI 2014 game schedule
# Scraped CHI 2015 game schedule
# Scraped CHI 2016 game schedule
# Scraped CHI 2017 game schedule
# Scraped CHI 2018 game schedule
# Scraped CHI 2019 game schedule
# Scraped CHI 2020 game schedule
# Scraped CHI 2021 game schedule
# Scraped CHI 2022 game schedule
# Scraped CHI 2023 game schedule
# Scraped multi-season schedule - CHI game schedule 2013 - 2023
# Finished scraping for team: CHI
# Scraped CHO 2015 game schedule
# Scraped CHO 2016 game schedule
# Scraped CHO 2017 game schedule
# Scraped CHO 2018 game schedule
# Scraped CHO 2019 game schedule
# Scraped CHO 2020 game schedule
# Scraped CHO 2021 game schedule
# Scraped CHO 2022 game schedule
# Scraped CHO 2023 game schedule
# Scraped multi-season schedule - CHO game schedule 2013 - 2023
# Finished scraping for team: CHO
# Scraped CLE 2013 game schedule
# Scraped CLE 2014 game schedule
# Scraped CLE 2015 game schedule
# Scraped CLE 2016 game schedule
# Scraped CLE 2017 game schedule
# Scraped CLE 2018 game schedule
# Scraped CLE 2019 game schedule
# Scraped CLE 2020 game schedule
# Scraped CLE 2021 game schedule
# Scraped CLE 2022 game schedule
# Scraped CLE 2023 game schedule
# Scraped multi-season schedule - CLE game schedule 2013 - 2023
# Finished scraping for team: CLE
# Scraped DAL 2013 game schedule
# Scraped DAL 2014 game schedule
# Scraped DAL 2015 game schedule
# Scraped DAL 2016 game schedule
# Scraped DAL 2017 game schedule
# Scraped DAL 2018 game schedule
# Scraped DAL 2019 game schedule
# Scraped DAL 2020 game schedule
# Scraped DAL 2021 game schedule
# Scraped DAL 2022 game schedule
# Scraped DAL 2023 game schedule
# Scraped multi-season schedule - DAL game schedule 2013 - 2023
# Finished scraping for team: DAL
# Scraped DEN 2013 game schedule
# Scraped DEN 2014 game schedule
# Scraped DEN 2015 game schedule
# Scraped DEN 2016 game schedule
# Scraped DEN 2017 game schedule
# Scraped DEN 2018 game schedule
# Scraped DEN 2019 game schedule
# Scraped DEN 2020 game schedule
# Scraped DEN 2021 game schedule
# Scraped DEN 2022 game schedule
# Scraped DEN 2023 game schedule
# Scraped multi-season schedule - DEN game schedule 2013 - 2023
# Finished scraping for team: DEN
# Scraped DET 2013 game schedule
# Scraped DET 2014 game schedule
# Scraped DET 2015 game schedule
# Scraped DET 2016 game schedule
# Scraped DET 2017 game schedule
# Scraped DET 2018 game schedule
# Scraped DET 2019 game schedule
# Scraped DET 2020 game schedule
# Scraped DET 2021 game schedule
# Scraped DET 2022 game schedule
# Scraped DET 2023 game schedule
# Scraped multi-season schedule - DET game schedule 2013 - 2023
# Finished scraping for team: DET
# Scraped GSW 2013 game schedule
# Scraped GSW 2014 game schedule
# Scraped GSW 2015 game schedule
# Scraped GSW 2016 game schedule
# Scraped GSW 2017 game schedule
# Scraped GSW 2018 game schedule
# Scraped GSW 2019 game schedule
# Scraped GSW 2020 game schedule
# Scraped GSW 2021 game schedule
# Scraped GSW 2022 game schedule
# Scraped GSW 2023 game schedule
# Scraped multi-season schedule - GSW game schedule 2013 - 2023
# Finished scraping for team: GSW
# Scraped HOU 2013 game schedule
# Scraped HOU 2014 game schedule
# Scraped HOU 2015 game schedule
# Scraped HOU 2016 game schedule
# Scraped HOU 2017 game schedule
# Scraped HOU 2018 game schedule
# Scraped HOU 2019 game schedule
# Scraped HOU 2020 game schedule
# Scraped HOU 2021 game schedule
# Scraped HOU 2022 game schedule
# Scraped HOU 2023 game schedule
# Scraped multi-season schedule - HOU game schedule 2013 - 2023
# Finished scraping for team: HOU
# Scraped IND 2013 game schedule
# Scraped IND 2014 game schedule
# Scraped IND 2015 game schedule
# Scraped IND 2016 game schedule
# Scraped IND 2017 game schedule
# Scraped IND 2018 game schedule
# Scraped IND 2019 game schedule
# Scraped IND 2020 game schedule
# Scraped IND 2021 game schedule
# Scraped IND 2022 game schedule
# Scraped IND 2023 game schedule
# Scraped multi-season schedule - IND game schedule 2013 - 2023
# Finished scraping for team: IND
# Scraped LAC 2013 game schedule
# Scraped LAC 2014 game schedule
# Scraped LAC 2015 game schedule
# Scraped LAC 2016 game schedule
# Scraped LAC 2017 game schedule
# Scraped LAC 2018 game schedule
# Scraped LAC 2019 game schedule
# Scraped LAC 2020 game schedule
# Scraped LAC 2021 game schedule
# Scraped LAC 2022 game schedule
# Scraped LAC 2023 game schedule
# Scraped multi-season schedule - LAC game schedule 2013 - 2023
# Finished scraping for team: LAC
# Scraped LAL 2013 game schedule
# Scraped LAL 2014 game schedule
# Scraped LAL 2015 game schedule
# Scraped LAL 2016 game schedule
# Scraped LAL 2017 game schedule
# Scraped LAL 2018 game schedule
# Scraped LAL 2019 game schedule
# Scraped LAL 2020 game schedule
# Scraped LAL 2021 game schedule
# Scraped LAL 2022 game schedule
# Scraped LAL 2023 game schedule
# Scraped multi-season schedule - LAL game schedule 2013 - 2023
# Finished scraping for team: LAL
# Scraped MEM 2013 game schedule
# Scraped MEM 2014 game schedule
# Scraped MEM 2015 game schedule
# Scraped MEM 2016 game schedule
# Scraped MEM 2017 game schedule
# Scraped MEM 2018 game schedule
# Scraped MEM 2019 game schedule
# Scraped MEM 2020 game schedule
# Scraped MEM 2021 game schedule
# Scraped MEM 2022 game schedule
# Scraped MEM 2023 game schedule
# Scraped multi-season schedule - MEM game schedule 2013 - 2023
# Finished scraping for team: MEM
# Scraped MIA 2013 game schedule
# Scraped MIA 2014 game schedule
# Scraped MIA 2015 game schedule
# Scraped MIA 2016 game schedule
# Scraped MIA 2017 game schedule
# Scraped MIA 2018 game schedule
# Scraped MIA 2019 game schedule
# Scraped MIA 2020 game schedule
# Scraped MIA 2021 game schedule
# Scraped MIA 2022 game schedule
# Scraped MIA 2023 game schedule
# Scraped multi-season schedule - MIA game schedule 2013 - 2023
# Finished scraping for team: MIA
# Scraped MIL 2013 game schedule
# Scraped MIL 2014 game schedule
# Scraped MIL 2015 game schedule
# Scraped MIL 2016 game schedule
# Scraped MIL 2017 game schedule
# Scraped MIL 2018 game schedule
# Scraped MIL 2019 game schedule
# Scraped MIL 2020 game schedule
# Scraped MIL 2021 game schedule
# Scraped MIL 2022 game schedule
# Scraped MIL 2023 game schedule
# Scraped multi-season schedule - MIL game schedule 2013 - 2023
# Finished scraping for team: MIL
# Scraped MIN 2013 game schedule
# Scraped MIN 2014 game schedule
# Scraped MIN 2015 game schedule
# Scraped MIN 2016 game schedule
# Scraped MIN 2017 game schedule
# Scraped MIN 2018 game schedule
# Scraped MIN 2019 game schedule
# Scraped MIN 2020 game schedule
# Scraped MIN 2021 game schedule
# Scraped MIN 2022 game schedule
# Scraped MIN 2023 game schedule
# Scraped multi-season schedule - MIN game schedule 2013 - 2023
# Finished scraping for team: MIN
# Scraped NOH 2013 game schedule
# Scraped multi-season schedule - NOH game schedule 2013 - 2023
# Finished scraping for team: NOH
# Scraped NOP 2014 game schedule
# Scraped NOP 2015 game schedule
# Scraped NOP 2016 game schedule
# Scraped NOP 2017 game schedule
# Scraped NOP 2018 game schedule
# Scraped NOP 2019 game schedule
# Scraped NOP 2020 game schedule
# Scraped NOP 2021 game schedule
# Scraped NOP 2022 game schedule
# Scraped NOP 2023 game schedule
# Scraped multi-season schedule - NOP game schedule 2013 - 2023
# Finished scraping for team: NOP
# Scraped NYK 2013 game schedule
# Scraped NYK 2014 game schedule
# Scraped NYK 2015 game schedule
# Scraped NYK 2016 game schedule
# Scraped NYK 2017 game schedule
# Scraped NYK 2018 game schedule
# Scraped NYK 2019 game schedule
# Scraped NYK 2020 game schedule
# Scraped NYK 2021 game schedule
# Scraped NYK 2022 game schedule
# Scraped NYK 2023 game schedule
# Scraped multi-season schedule - NYK game schedule 2013 - 2023
# Finished scraping for team: NYK
# Scraped OKC 2013 game schedule
# Scraped OKC 2014 game schedule
# Scraped OKC 2015 game schedule
# Scraped OKC 2016 game schedule
# Scraped OKC 2017 game schedule
# Scraped OKC 2018 game schedule
# Scraped OKC 2019 game schedule
# Scraped OKC 2020 game schedule
# Scraped OKC 2021 game schedule
# Scraped OKC 2022 game schedule
# Scraped OKC 2023 game schedule
# Scraped multi-season schedule - OKC game schedule 2013 - 2023
# Finished scraping for team: OKC
# Scraped ORL 2013 game schedule
# Scraped ORL 2014 game schedule
# Scraped ORL 2015 game schedule
# Scraped ORL 2016 game schedule
# Scraped ORL 2017 game schedule
# Scraped ORL 2018 game schedule
# Scraped ORL 2019 game schedule
# Scraped ORL 2020 game schedule
# Scraped ORL 2021 game schedule
# Scraped ORL 2022 game schedule
# Scraped ORL 2023 game schedule
# Scraped multi-season schedule - ORL game schedule 2013 - 2023
# Finished scraping for team: ORL
# Scraped PHI 2013 game schedule
# Scraped PHI 2014 game schedule
# Scraped PHI 2015 game schedule
# Scraped PHI 2016 game schedule
# Scraped PHI 2017 game schedule
# Scraped PHI 2018 game schedule
# Scraped PHI 2019 game schedule
# Scraped PHI 2020 game schedule
# Scraped PHI 2021 game schedule
# Scraped PHI 2022 game schedule
# Scraped PHI 2023 game schedule
# Scraped multi-season schedule - PHI game schedule 2013 - 2023
# Finished scraping for team: PHI
# Scraped PHO 2013 game schedule
# Scraped PHO 2014 game schedule
# Scraped PHO 2015 game schedule
# Scraped PHO 2016 game schedule
# Scraped PHO 2017 game schedule
# Scraped PHO 2018 game schedule
# Scraped PHO 2019 game schedule
# Scraped PHO 2020 game schedule
# Scraped PHO 2021 game schedule
# Scraped PHO 2022 game schedule
# Scraped PHO 2023 game schedule
# Scraped multi-season schedule - PHO game schedule 2013 - 2023
# Finished scraping for team: PHO
# Scraped POR 2013 game schedule
# Scraped POR 2014 game schedule
# Scraped POR 2015 game schedule
# Scraped POR 2016 game schedule
# Scraped POR 2017 game schedule
# Scraped POR 2018 game schedule
# Scraped POR 2019 game schedule
# Scraped POR 2020 game schedule
# Scraped POR 2021 game schedule
# Scraped POR 2022 game schedule
# Scraped POR 2023 game schedule
# Scraped multi-season schedule - POR game schedule 2013 - 2023
# Finished scraping for team: POR
# Scraped SAC 2013 game schedule
# Scraped SAC 2014 game schedule
# Scraped SAC 2015 game schedule
# Scraped SAC 2016 game schedule
# Scraped SAC 2017 game schedule
# Scraped SAC 2018 game schedule
# Scraped SAC 2019 game schedule
# Scraped SAC 2020 game schedule
# Scraped SAC 2021 game schedule
# Scraped SAC 2022 game schedule
# Scraped SAC 2023 game schedule
# Scraped multi-season schedule - SAC game schedule 2013 - 2023
# Finished scraping for team: SAC
# Scraped SAS 2013 game schedule
# Scraped SAS 2014 game schedule
# Scraped SAS 2015 game schedule
# Scraped SAS 2016 game schedule
# Scraped SAS 2017 game schedule
# Scraped SAS 2018 game schedule
# Scraped SAS 2019 game schedule
# Scraped SAS 2020 game schedule
# Scraped SAS 2021 game schedule
# Scraped SAS 2022 game schedule
# Scraped SAS 2023 game schedule
# Scraped multi-season schedule - SAS game schedule 2013 - 2023
# Finished scraping for team: SAS
# Scraped TOR 2013 game schedule
# Scraped TOR 2014 game schedule
# Scraped TOR 2015 game schedule
# Scraped TOR 2016 game schedule
# Scraped TOR 2017 game schedule
# Scraped TOR 2018 game schedule
# Scraped TOR 2019 game schedule
# Scraped TOR 2020 game schedule
# Scraped TOR 2021 game schedule
# Scraped TOR 2022 game schedule
# Scraped TOR 2023 game schedule
# Scraped multi-season schedule - TOR game schedule 2013 - 2023
# Finished scraping for team: TOR
# Scraped UTA 2013 game schedule
# Scraped UTA 2014 game schedule
# Scraped UTA 2015 game schedule
# Scraped UTA 2016 game schedule
# Scraped UTA 2017 game schedule
# Scraped UTA 2018 game schedule
# Scraped UTA 2019 game schedule
# Scraped UTA 2020 game schedule
# Scraped UTA 2021 game schedule
# Scraped UTA 2022 game schedule
# Scraped UTA 2023 game schedule
# Scraped multi-season schedule - UTA game schedule 2013 - 2023
# Finished scraping for team: UTA
# Scraped WAS 2013 game schedule
# Scraped WAS 2014 game schedule
# Scraped WAS 2015 game schedule
# Scraped WAS 2016 game schedule
# Scraped WAS 2017 game schedule
# Scraped WAS 2018 game schedule
# Scraped WAS 2019 game schedule
# Scraped WAS 2020 game schedule
# Scraped WAS 2021 game schedule
# Scraped WAS 2022 game schedule
# Scraped WAS 2023 game schedule
# Scraped multi-season schedule - WAS game schedule 2013 - 2023
# Finished scraping for team: WAS
# Saving master file
# Finished
